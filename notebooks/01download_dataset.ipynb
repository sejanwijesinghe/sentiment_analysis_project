# %%
import numpy as np

# %%
import json
with open('..//artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'sejanwijesinghe', 'key': 'KGAT_767b53136f9749d5b8cf5b5a3c52db06'}

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (1.7.4.5)
# Requirement already satisfied: bleach in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2026.1.4)
# Requirement already satisfied: charset-normalizer in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\users\sejan sadev\desktop\sentiment_analysis_project\env\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_dou
